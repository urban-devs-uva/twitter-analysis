# %%
import pandas as pd

twitter_df = pd.read_csv('tweets_data4.csv', encoding='utf-8')

display(twitter_df)
# Out:
#                                                 Keyword  \
# 0     buurthub OR deelvervoer OR deelauto OR deelfie...
# 1     buurthub OR deelvervoer OR deelauto OR deelfie...
# 2     buurthub OR deelvervoer OR deelauto OR deelfie...
# 3     buurthub OR deelvervoer OR deelauto OR deelfie...
# 4     buurthub OR deelvervoer OR deelauto OR deelfie...
# ...                                                 ...
# 1035  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1036  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1037  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1038  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1039  buurthub OR deelvervoer OR deelauto OR deelfie...
#
#                                              Tweet Text
# 0     @PekePeter @Nieuwsblad_be @groen Dan is het we...
# 1     Wéér trekt een aanbieder van deelvervoer zich ...
# 2     #Tinyhouses #Westpark #Groningen Er gebeurt hi...
# 3     Autodelen of een deelauto. Ideaal te combinere...
# 4     Vandaag is tevens de start van de landelijke c...
# ...                                                 ...
# 1035  @TNYBN123 @z0roProfit Een deelauto wordt door ...
# 1036  Deelfiets in brand bij bushalte in Gorinchem: ...
# 1037  Deelfiets in brand bij bushalte in Gorinchem: ...
# 1038  Nieuws: Deelfiets in brand bij bushalte in Gor...
# 1039  Heb vanochtend mijn deelfiets aangedreven op s...
#
# [1040 rows x 2 columns]

# %%
from deep_translator import GoogleTranslator

twitter_df['Translated Text'] = twitter_df['Tweet Text'].apply(
    lambda x: GoogleTranslator(source='auto', target='en').translate(x)
)

# %%
display(twitter_df['Translated Text'])
# Out:
# 0       @PekePeter @Nieuwsblad_be @groen Then it is st...
# 1       Once again a shared transport provider is with...
# 2       #Tinyhouses #Westpark #Groningen There is much...
# 3       Car sharing or a shared car. Ideal to combine ...
# 4       Today is also the start of the national campai...
#                               ...
# 1035    @TNYBN123 @z0roProfit A shared car is used by ...
# 1036    Shared bicycle on fire at bus stop in Gorinche...
# 1037    Shared bicycle on fire at bus stop in Gorinche...
# 1038    News: Bicycle sharing on fire at bus stop in G...
# 1039    This morning I parked my shared bicycle powere...
# Name: Translated Text, Length: 1040, dtype: object

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re

from nltk.stem import WordNetLemmatizer
from nltk.corpus import words
from gensim import corpora
from gensim.models.ldamodel import LdaModel

english_words = set(words.words())

lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    # YOUR CODE HERE
    text = str(text) if isinstance(text, (str, float)) else ''

    # Remove Twitter handles
    text = re.sub(r'@[\w_]+', '', text)

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    text = text.translate(str.maketrans('', '', string.punctuation))

    #remove special characters
    text= re.sub(r'[^A-Za-z\s]', '', text)

    #case normalisation
    text = text.lower()

    #tokenisation
    tokens = word_tokenize(text)

    #removal of stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and token in english_words]
        
    #lemmatisation
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return tokens


texts = twitter_df['Translated Text'].tolist()

processed_texts = [preprocess_text(text) for text in texts]

corpus = corpora.Dictionary(processed_texts)

doc_term_matrix = [corpus.doc2bow(text) for text in processed_texts]

print(processed_texts)
# Out:
# [['stupid', 'target', 'car'], ['transport', 'provider', 'withdrawing', 'used', 'enough'], ['much', 'going', 'living', 'number', 'sold', 'driving', 'number', 'electric'], ['car', 'car', 'ideal', 'combine', 'frequent', 'cycling', 'public', 'transport', 'starting', 'great', 'campaign', 'also', 'discount', 'new'], ['today', 'also', 'start', 'national', 'campaign', 'car', 'world', 'beautiful', 'read', 'car', 'view', 'various', 'discount', 'car'], ['electric', 'great', 'potential', 'achieve', 'sustainable', 'future', 'organize', 'well', 'municipality', 'full', 'fast', 'charger', 'everything'], ['thinking', 'behind', 'used', 'also', 'people', 'higher', 'expensive'], ['car', 'tax', 'money', 'work', 'pleasure', 'young', 'people', 'provide', 'tomorrow'], ['safety', 'lock', 'must', 'ensure', 'intoxicated', 'user', 'leaf', 'scooter', 'behind'], ['nice', 'thread', 'high', 'time', 'clear', 'choice', 'bicycle', 'public', 'transport', 'car', 'huge', 'amount', 'space', 'pollution', 'noise', 'pollution', 'traffic', 'traffic', 'way', 'make', 'transport', 'affordable', 'people', 'little', 'money'], ['young', 'people', 'set', 'fire', 'car', 'laugh', 'rushing', 'police', 'climate', 'change', 'better', 'car', 'car', 'working', 'person'], ['standard', 'assumed', 'permanent', 'also', 'come', 'table', 'ask'], ['back', 'top', 'also', 'scooter', 'first', 'report', 'still', 'resolved', 'let', 'municipality', 'know'], ['mobility', 'hub', 'bicycle', 'parking', 'space', 'keep', 'outside', 'center'], ['college', 'mobility'], ['alcohol', 'lock', 'scooter', 'keep', 'drunk', 'traffic'], ['safety', 'lock', 'must', 'ensure', 'intoxicated', 'user', 'leaf', 'scooter', 'behind'], ['used', 'drunken', 'young', 'people', 'criminal', 'therefore', 'dangerous', 'security', 'lock', 'ending', 'scooter', 'pilot', 'better', 'especially', 'option'], ['used', 'travel', 'train', 'pleasure', 'fairly', 'reliable', 'nowadays', 'absolutely', 'idea', 'whether', 'even', 'arrive', 'destination', 'whether', 'get', 'home', 'would', 'car', 'something', 'cant', 'buy', 'car', 'either', 'expensive'], ['want', 'curious', 'first', 'ride', 'car', 'drive', 'handy', 'affordable', 'wonderfully', 'sustainable', 'also', 'want', 'make', 'impact', 'together', 'book', 'first', 'ride', 'receive', 'discount'], ['recognize', 'drama', 'east', 'country', 'even', 'worse', 'run', 'default', 'exceptionally', 'bizarre', 'nowadays', 'travel', 'little', 'possible', 'train', 'necessary', 'taxi', 'consider', 'car', 'share'], ['help', 'x', 'posse', 'complete', 'survey', 'share', 'call', 'people', 'context', 'thesis', 'geography', 'research', 'gender', 'gap', 'use', 'bike', 'electric', 'bike', 'scooter', 'region', 'help', 'enormously', 'survey', 'need', 'experience', 'mobility', 'yet', 'link'], ['never', 'completely', 'disappear', 'city', 'many', 'easily', 'car', 'already', 'many', 'take', 'shape'], ['lot', 'new', 'information', 'come', 'user', 'research', 'actually', 'data', 'interesting', 'conduct', 'type', 'research', 'read', 'research'], ['councilor', 'used', 'smart', 'tire', 'pump', 'band', 'took', 'car', 'tire', 'pump', 'average', 'use', 'pump', 'per', 'week', 'pump', 'free', 'found', 'ah'], ['everyone', 'drive', 'electric', 'need', 'car', 'already', 'electric'], ['goodness', 'get', 'beautiful', 'minute', 'would', 'fly', 'credit', 'score', 'high', 'enough', 'ride', 'bike'], ['nice', 'rescue', 'car', 'good', 'trip'], ['next', 'year', 'longer', 'leave', 'bicycle', 'scooter', 'anywhere'], ['electric', 'little', 'creativity', 'instead', 'eternal', 'struggle', 'money', 'mean', 'money', 'minimum', 'income', 'inventive'], ['next', 'year', 'longer', 'leave', 'bicycle', 'scooter', 'everywhere'], ['next', 'year', 'longer', 'leave', 'bicycle', 'scooter', 'everywhere'], ['go', 'straight', 'catch', 'flight', 'train', 'doesnt', 'work', 'car', 'taken', 'running', 'airport', 'take', 'suitcase', 'u', 'made', 'flight', 'cry', 'eldest', 'daughter'], ['morning', 'traveled', 'unknown', 'territory', 'way', 'back', 'turned', 'taken',  ...

# %%
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer

def analyze_topics(texts):
    # Concatenate the lists of tweets into a single string for each document
    concatenated_texts = [' '.join(tweet_list) for tweet_list in texts]

    ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)

    # Create BERTopic model
    model = BERTopic(verbose=True, embedding_model='paraphrase-MiniLM-L3-v2', min_topic_size=5, ctfidf_model=ctfidf_model)

    # Fit and transform the model on the concatenated texts
    topics, _ = model.fit_transform(concatenated_texts)

    # Get topic frequency information
    freq = model.get_topic_info()

    
    print("Number of topics: {}".format(len(freq)))
    display(freq.head(50))

    freq = model.get_topic_info()
    freq.to_csv('output2.csv', index=False)

    return model, topics

# Assuming processed_texts is a list of lists containing content from different tweets
model, topics = analyze_topics(processed_texts)
# Out:
# Batches:   0%|          | 0/33 [00:00<?, ?it/s]
# 2023-12-11 18:31:11,656 - BERTopic - Transformed documents to Embeddings
# 2023-12-11 18:31:22,788 - BERTopic - Reduced dimensionality
# 2023-12-11 18:31:22,865 - BERTopic - Clustered reduced embeddings
# Number of topics: 38
#     Topic  Count                                          Name  \
# 0      -1    309                      -1_would_dont_take_drive
# 1       0     84                     0_scooter_bench_hit_delft
# 2       1     75                 1_public_transport_become_get
# 3       2     52                     2_bicycle_bike_fire_water
# 4       3     44              3_like_variant_sawing_preferably
# 5       4     43      4_hub_neighborhood_district_consultation
# 6       5     38                  5_parking_space_permit_fixed
# 7       6     28          6_premium_electric_interest_becoming
# 8       7     27                 7_rental_rent_ownership_lease
# 9       8     26                 8_electric_opt_already_invest
# 10      9     24         9_mobility_hub_transfer_accessibility
# 11     10     23                 10_public_never_poor_everyone
# 12     11     20    11_expensive_subscription_occasionally_use
# 13     12     18                     12_bus_bicycle_train_tram
# 14     13     16              13_distance_within_walking_grown
# 15     14     15              14_battery_power_possible_supply
# 16     15     13        15_mobility_encouraging_growth_license
# 17     16     13                  16_great_streak_strange_dive
# 18     17     12          17_endura_initiative_project_meeting
# 19     18     12             18_electricity_world_supply_first
# 20     19     11                  19_flown_popular_top_evident
# 21     20     10                 20_none_nobody_never_everyone
# 22     21     10        21_battery_neighborhood_provide_entire
# 23     22     10                22_success_center_make_parking
# 24     23      9               23_private_honest_ban_ownership
# 25     24      9                24_research_user_report_impact
# 26     25      9               25_pressure_combat_hassle_quite
# 27     26      8                       26_rid_happy_idea_right
# 28     27      8                 27_ride_book_trip_wonderfully
# 29     28      8  28_charging_infrastructure_municipality_plan
# 30     29      8               29_solar_drive_collaborate_hand
# 31     30      8        30_cycling_walking_objection_pollution
# 32     31      8            31_fleet_flemish_powered_passenger
# 33     32      7            32_crazy_madness_perhaps_certainly
# 34     33      7               33_questionnaire_let_short_know
# 35     34      7                 34_tax_green_motion_introduce
# 36     35      6               35_supply_growing_growth_plenty
# 37     36      5                     36_front_door_two_pursuit
#
#                                        Representation  \
# 0   [would, dont, take, drive, still, also, use, w...
# 1   [scooter, bench, hit, delft, sidewalk, blind, ...
# 2   [public, transport, become, get, future, west,...
# 3   [bicycle, bike, fire, water, velo, injured, br...
# 4   [like, variant, sawing, preferably, taxi, stil...
# 5   [hub, neighborhood, district, consultation, en...
# 6   [parking, space, permit, fixed, moment, privat...
# 7   [premium, electric, interest, becoming, expect...
# 8   [rental, rent, ownership, lease, pay, even, us...
# 9   [electric, opt, already, invest, might, increa...
# 10  [mobility, hub, transfer, accessibility, colle...
# 11  [public, never, poor, everyone, without, neces...
# 12  [expensive, subscription, occasionally, use, e...
# 13  [bus, bicycle, train, tram, hop, public, commu...
# 14  [distance, within, walking, grown, number, per...
# 15  [battery, power, possible, supply, work, one, ...
# 16  [mobility, encouraging, growth, license, susta...
# 17  [great, streak, strange, dive, communist, hey,...
# 18  [endura, initiative, project, meeting, ambitio...
# 19  [electricity, world, supply, first, energy, re...
# 20  [flown, popular, top, evident, especially, spr...
# 21  [none, nobody, never, everyone, police, theori...
# 22  [battery, neighborhood, provide, entire, eveni...
# 23  [success, center, make, parking, city, flexibl...
# 24  [private, honest, ban, ownership, instead, nee...
# 25  [research, user, report, impact, survey, launc...
# 26  [pressure, combat, hassle, quite, sometimes, p...
# 27  [rid, happy, idea, right, get, good, wear, tea...
# 28  [ride, book, trip, wonderfully, first, discoun...
# 29  [charging, infrastructure, municipality, plan,...
# 30  [solar, drive, collaborate, hand, collaboratio...
# 31  [cycling, walking, objection, pollution, green...
# 32  [fleet, flemish, powered, passenger, electrica...
# 33  [crazy, madness, perhaps, certainly, city, man...
# 34  [questionnaire, let, short, know, think, siste...
# 35  [tax, green, motion, introduce, investigating,...
# 36  [supply, growing, growth, plenty, already, ava...
# 37  [front, door, two, pursuit, shower, yard, thou...
#
#                                   Representative_Docs
# 0   [buy car car le, better buy car car interestin...
# 1   [scooter go district delft, back scooter, scoo...
# 2   [affordable reliable public transport electric...
# 3            [bike, bike, fire brigade bicycle water]
# 4                                     [car, car, car]
# 5   [consultation supervision enforcement another ...
# 6   [plenty available several excellent alternativ...
# 7   [already possible rent electric may also possi...
# 8   [car end car ownership, thats right combinatio...
# 9   [without car opt car already electric, electri...
# 10  [know transfer hub current learn pay transfer ...
# 11  [time follow mobility people make car research...
# 12  [interesting often drive car need car occasion...
# 13  [switch bicycle train car bus tram people rura...
# 14  [top looking number per share car within walki...
# 15  [battery one electric car supply power possibl...
# 16  [actively affordable mobility help bit people ...
# 17  [great strange, thats communist streak, great ...
# 18  [share car together neighborhood endura projec...
# 19  [world first supply electricity, world first s...
# 20  [nice news number last year evident annual sur...
# 21  [leave nothing happy car maybe car unaffordabl...
# 22  [charge day evening provide entire neighborhoo...
# 23  [parking city center make transport success, p...
# 24  [assumption could replace still private owners...
# 25  [curious user research important found knowing...
# 26  [well combat parking pressure sometimes quite ...
# 27  [happy yet also disappearing longer map right ...
# 28  [want curious first ride car drive handy affor...
# 29  [municipality charging electric, municipality ...
# 30  [drive solar charge anywhere innovation go han...
# 31  [yet received answer objection expansion trans...
# 32  [entire fleet already electric considerably hi...
# 33  [madness time car certainly work many people w...
# 34  [bicycle scooter car think let u know via shor...
# 35  [appreciation motion member van investigating ...
# 36  [quick look market looking north many currentl...
# 37  [offer car car via fact drive car front door i...

# %%
topics_df = pd.read_csv('output2.csv', sep=',')
display(topics_df)
# Out:
#     Topic  Count                                          Name  \
# 0      -1    309                      -1_would_dont_take_drive
# 1       0     84                     0_scooter_bench_hit_delft
# 2       1     75                 1_public_transport_become_get
# 3       2     52                     2_bicycle_bike_fire_water
# 4       3     44              3_like_variant_sawing_preferably
# 5       4     43      4_hub_neighborhood_district_consultation
# 6       5     38                  5_parking_space_permit_fixed
# 7       6     28          6_premium_electric_interest_becoming
# 8       7     27                 7_rental_rent_ownership_lease
# 9       8     26                 8_electric_opt_already_invest
# 10      9     24         9_mobility_hub_transfer_accessibility
# 11     10     23                 10_public_never_poor_everyone
# 12     11     20    11_expensive_subscription_occasionally_use
# 13     12     18                     12_bus_bicycle_train_tram
# 14     13     16              13_distance_within_walking_grown
# 15     14     15              14_battery_power_possible_supply
# 16     15     13        15_mobility_encouraging_growth_license
# 17     16     13                  16_great_streak_strange_dive
# 18     17     12          17_endura_initiative_project_meeting
# 19     18     12             18_electricity_world_supply_first
# 20     19     11                  19_flown_popular_top_evident
# 21     20     10                 20_none_nobody_never_everyone
# 22     21     10        21_battery_neighborhood_provide_entire
# 23     22     10                22_success_center_make_parking
# 24     23      9               23_private_honest_ban_ownership
# 25     24      9                24_research_user_report_impact
# 26     25      9               25_pressure_combat_hassle_quite
# 27     26      8                       26_rid_happy_idea_right
# 28     27      8                 27_ride_book_trip_wonderfully
# 29     28      8  28_charging_infrastructure_municipality_plan
# 30     29      8               29_solar_drive_collaborate_hand
# 31     30      8        30_cycling_walking_objection_pollution
# 32     31      8            31_fleet_flemish_powered_passenger
# 33     32      7            32_crazy_madness_perhaps_certainly
# 34     33      7               33_questionnaire_let_short_know
# 35     34      7                 34_tax_green_motion_introduce
# 36     35      6               35_supply_growing_growth_plenty
# 37     36      5                     36_front_door_two_pursuit
#
#                                        Representation  \
# 0   ['would', 'dont', 'take', 'drive', 'still', 'a...
# 1   ['scooter', 'bench', 'hit', 'delft', 'sidewalk...
# 2   ['public', 'transport', 'become', 'get', 'futu...
# 3   ['bicycle', 'bike', 'fire', 'water', 'velo', '...
# 4   ['like', 'variant', 'sawing', 'preferably', 't...
# 5   ['hub', 'neighborhood', 'district', 'consultat...
# 6   ['parking', 'space', 'permit', 'fixed', 'momen...
# 7   ['premium', 'electric', 'interest', 'becoming'...
# 8   ['rental', 'rent', 'ownership', 'lease', 'pay'...
# 9   ['electric', 'opt', 'already', 'invest', 'migh...
# 10  ['mobility', 'hub', 'transfer', 'accessibility...
# 11  ['public', 'never', 'poor', 'everyone', 'witho...
# 12  ['expensive', 'subscription', 'occasionally', ...
# 13  ['bus', 'bicycle', 'train', 'tram', 'hop', 'pu...
# 14  ['distance', 'within', 'walking', 'grown', 'nu...
# 15  ['battery', 'power', 'possible', 'supply', 'wo...
# 16  ['mobility', 'encouraging', 'growth', 'license...
# 17  ['great', 'streak', 'strange', 'dive', 'commun...
# 18  ['endura', 'initiative', 'project', 'meeting',...
# 19  ['electricity', 'world', 'supply', 'first', 'e...
# 20  ['flown', 'popular', 'top', 'evident', 'especi...
# 21  ['none', 'nobody', 'never', 'everyone', 'polic...
# 22  ['battery', 'neighborhood', 'provide', 'entire...
# 23  ['success', 'center', 'make', 'parking', 'city...
# 24  ['private', 'honest', 'ban', 'ownership', 'ins...
# 25  ['research', 'user', 'report', 'impact', 'surv...
# 26  ['pressure', 'combat', 'hassle', 'quite', 'som...
# 27  ['rid', 'happy', 'idea', 'right', 'get', 'good...
# 28  ['ride', 'book', 'trip', 'wonderfully', 'first...
# 29  ['charging', 'infrastructure', 'municipality',...
# 30  ['solar', 'drive', 'collaborate', 'hand', 'col...
# 31  ['cycling', 'walking', 'objection', 'pollution...
# 32  ['fleet', 'flemish', 'powered', 'passenger', '...
# 33  ['crazy', 'madness', 'perhaps', 'certainly', '...
# 34  ['questionnaire', 'let', 'short', 'know', 'thi...
# 35  ['tax', 'green', 'motion', 'introduce', 'inves...
# 36  ['supply', 'growing', 'growth', 'plenty', 'alr...
# 37  ['front', 'door', 'two', 'pursuit', 'shower', ...
#
#                                   Representative_Docs
# 0   ['buy car car le', 'better buy car car interes...
# 1   ['scooter go district delft', 'back scooter', ...
# 2   ['affordable reliable public transport electri...
# 3      ['bike', 'bike', 'fire brigade bicycle water']
# 4                               ['car', 'car', 'car']
# 5   ['consultation supervision enforcement another...
# 6   ['plenty available several excellent alternati...
# 7   ['already possible rent electric may also poss...
# 8   ['car end car ownership', 'thats right combina...
# 9   ['without car opt car already electric', 'elec...
# 10  ['know transfer hub current learn pay transfer...
# 11  ['time follow mobility people make car researc...
# 12  ['interesting often drive car need car occasio...
# 13  ['switch bicycle train car bus tram people rur...
# 14  ['top looking number per share car within walk...
# 15  ['battery one electric car supply power possib...
# 16  ['actively affordable mobility help bit people...
# 17  ['great strange', 'thats communist streak', 'g...
# 18  ['share car together neighborhood endura proje...
# 19  ['world first supply electricity', 'world firs...
# 20  ['nice news number last year evident annual su...
# 21  ['leave nothing happy car maybe car unaffordab...
# 22  ['charge day evening provide entire neighborho...
# 23  ['parking city center make transport success',...
# 24  ['assumption could replace still private owner...
# 25  ['curious user research important found knowin...
# 26  ['well combat parking pressure sometimes quite...
# 27  ['happy yet also disappearing longer map right...
# 28  ['want curious first ride car drive handy affo...
# 29  ['municipality charging electric', 'municipali...
# 30  ['drive solar charge anywhere innovation go ha...
# 31  ['yet received answer objection expansion tran...
# 32  ['entire fleet already electric considerably h...
# 33  ['madness time car certainly work many people ...
# 34  ['bicycle scooter car think let u know via sho...
# 35  ['appreciation motion member van investigating...
# 36  ['quick look market looking north many current...
# 37  ['offer car car via fact drive car front door ...

# %%
import requests

def analyze_sentiment(text):
    url = "http://text-processing.com/api/sentiment/"
    data = {'text': text, 'language': 'dutch'}

    response = requests.post(url, data=data)
    result = response.json()

    sentiment = result['label']
    confidence = result['probability'][sentiment]

    return sentiment, confidence


topics_df['sentiment'], topics_df['confidence'] = zip(*topics_df['Representative_Docs'].apply(analyze_sentiment))

print(topics_df[['Representative_Docs', 'sentiment', 'confidence']])
# Out:
#                                   Representative_Docs sentiment  confidence
# 0   ['buy car car le', 'better buy car car interes...   neutral        1.00
# 1   ['scooter go district delft', 'back scooter', ...   neutral        1.00
# 2   ['affordable reliable public transport electri...   neutral        1.00
# 3      ['bike', 'bike', 'fire brigade bicycle water']   neutral        1.00
# 4                               ['car', 'car', 'car']   neutral        1.00
# 5   ['consultation supervision enforcement another...   neutral        1.00
# 6   ['plenty available several excellent alternati...   neutral        1.00
# 7   ['already possible rent electric may also poss...   neutral        1.00
# 8   ['car end car ownership', 'thats right combina...   neutral        1.00
# 9   ['without car opt car already electric', 'elec...   neutral        1.00
# 10  ['know transfer hub current learn pay transfer...   neutral        1.00
# 11  ['time follow mobility people make car researc...       pos        0.70
# 12  ['interesting often drive car need car occasio...   neutral        1.00
# 13  ['switch bicycle train car bus tram people rur...   neutral        1.00
# 14  ['top looking number per share car within walk...   neutral        1.00
# 15  ['battery one electric car supply power possib...   neutral        1.00
# 16  ['actively affordable mobility help bit people...       neg        0.60
# 17  ['great strange', 'thats communist streak', 'g...   neutral        1.00
# 18  ['share car together neighborhood endura proje...   neutral        1.00
# 19  ['world first supply electricity', 'world firs...   neutral        1.00
# 20  ['nice news number last year evident annual su...       pos        0.70
# 21  ['leave nothing happy car maybe car unaffordab...   neutral        1.00
# 22  ['charge day evening provide entire neighborho...   neutral        1.00
# 23  ['parking city center make transport success',...   neutral        1.00
# 24  ['assumption could replace still private owner...       neg        0.60
# 25  ['curious user research important found knowin...   neutral        1.00
# 26  ['well combat parking pressure sometimes quite...   neutral        1.00
# 27  ['happy yet also disappearing longer map right...   neutral        1.00
# 28  ['want curious first ride car drive handy affo...   neutral        1.00
# 29  ['municipality charging electric', 'municipali...   neutral        1.00
# 30  ['drive solar charge anywhere innovation go ha...   neutral        1.00
# 31  ['yet received answer objection expansion tran...       pos        0.75
# 32  ['entire fleet already electric considerably h...   neutral        1.00
# 33  ['madness time car certainly work many people ...   neutral        1.00
# 34  ['bicycle scooter car think let u know via sho...   neutral        1.00
# 35  ['appreciation motion member van investigating...   neutral        1.00
# 36  ['quick look market looking north many current...   neutral        0.90
# 37  ['offer car car via fact drive car front door ...   neutral        0.70
