# %%
import pandas as pd

twitter_df = pd.read_csv('tweets_data4.csv', encoding='utf-8')

display(twitter_df)
# Out:
#                                                 Keyword  \
# 0     buurthub OR deelvervoer OR deelauto OR deelfie...
# 1     buurthub OR deelvervoer OR deelauto OR deelfie...
# 2     buurthub OR deelvervoer OR deelauto OR deelfie...
# 3     buurthub OR deelvervoer OR deelauto OR deelfie...
# 4     buurthub OR deelvervoer OR deelauto OR deelfie...
# ...                                                 ...
# 1035  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1036  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1037  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1038  buurthub OR deelvervoer OR deelauto OR deelfie...
# 1039  buurthub OR deelvervoer OR deelauto OR deelfie...
#
#                                              Tweet Text
# 0     @PekePeter @Nieuwsblad_be @groen Dan is het we...
# 1     Wéér trekt een aanbieder van deelvervoer zich ...
# 2     #Tinyhouses #Westpark #Groningen Er gebeurt hi...
# 3     Autodelen of een deelauto. Ideaal te combinere...
# 4     Vandaag is tevens de start van de landelijke c...
# ...                                                 ...
# 1035  @TNYBN123 @z0roProfit Een deelauto wordt door ...
# 1036  Deelfiets in brand bij bushalte in Gorinchem: ...
# 1037  Deelfiets in brand bij bushalte in Gorinchem: ...
# 1038  Nieuws: Deelfiets in brand bij bushalte in Gor...
# 1039  Heb vanochtend mijn deelfiets aangedreven op s...
#
# [1040 rows x 2 columns]

# %%
from deep_translator import GoogleTranslator

twitter_df['Translated Text'] = twitter_df['Tweet Text'].apply(
    lambda x: GoogleTranslator(source='auto', target='en').translate(x)
)

# %%
display(twitter_df['Translated Text'])
# Out:
# 0       @PekePeter @Nieuwsblad_be @groen Then it is st...
# 1       Once again a shared transport provider is with...
# 2       #Tinyhouses #Westpark #Groningen There is much...
# 3       Car sharing or a shared car. Ideal to combine ...
# 4       Today is also the start of the national campai...
#                               ...
# 1035    @TNYBN123 @z0roProfit A shared car is used by ...
# 1036    Shared bicycle on fire at bus stop in Gorinche...
# 1037    Shared bicycle on fire at bus stop in Gorinche...
# 1038    News: Bicycle sharing on fire at bus stop in G...
# 1039    This morning I parked my shared bicycle powere...
# Name: Translated Text, Length: 1040, dtype: object

# %%
twitter_df.to_csv('translated_tweets.csv', index=False)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import re

from nltk.stem import WordNetLemmatizer
from nltk.corpus import words
from gensim import corpora
from gensim.models.ldamodel import LdaModel

english_words = set(words.words())

lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = str(text) if isinstance(text, (str, float)) else ''

    #remove Twitter handles
    text = re.sub(r'@[\w_]+', '', text)

    #remove URLs
    text = re.sub(r'http\S+', '', text)

    text = text.translate(str.maketrans('', '', string.punctuation))

    #remove special characters
    text= re.sub(r'[^A-Za-z\s]', '', text)

    #case normalisation
    text = text.lower()

    #tokenisation
    tokens = word_tokenize(text)

    #removal of stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words and token in english_words]
        
    #lemmatisation
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return tokens


texts = twitter_df['Translated Text'].tolist()

processed_texts = [preprocess_text(text) for text in texts]

corpus = corpora.Dictionary(processed_texts)

doc_term_matrix = [corpus.doc2bow(text) for text in processed_texts]

print(processed_texts)
# Out:
# [['stupid', 'target', 'car'], ['transport', 'provider', 'withdrawing', 'used', 'enough'], ['much', 'going', 'living', 'number', 'sold', 'driving', 'number', 'electric'], ['car', 'car', 'ideal', 'combine', 'frequent', 'cycling', 'public', 'transport', 'starting', 'great', 'campaign', 'also', 'discount', 'new'], ['today', 'also', 'start', 'national', 'campaign', 'car', 'world', 'beautiful', 'read', 'car', 'view', 'various', 'discount', 'car'], ['electric', 'great', 'potential', 'achieve', 'sustainable', 'future', 'organize', 'well', 'municipality', 'full', 'fast', 'charger', 'everything'], ['thinking', 'behind', 'used', 'also', 'people', 'higher', 'expensive'], ['car', 'tax', 'money', 'work', 'pleasure', 'young', 'people', 'provide', 'tomorrow'], ['safety', 'lock', 'must', 'ensure', 'intoxicated', 'user', 'leaf', 'scooter', 'behind'], ['nice', 'thread', 'high', 'time', 'clear', 'choice', 'bicycle', 'public', 'transport', 'car', 'huge', 'amount', 'space', 'pollution', 'noise', 'pollution', 'traffic', 'traffic', 'way', 'make', 'transport', 'affordable', 'people', 'little', 'money'], ['young', 'people', 'set', 'fire', 'car', 'laugh', 'rushing', 'police', 'climate', 'change', 'better', 'car', 'car', 'working', 'person'], ['standard', 'assumed', 'permanent', 'also', 'come', 'table', 'ask'], ['back', 'top', 'also', 'scooter', 'first', 'report', 'still', 'resolved', 'let', 'municipality', 'know'], ['mobility', 'hub', 'bicycle', 'parking', 'space', 'keep', 'outside', 'center'], ['college', 'mobility'], ['alcohol', 'lock', 'scooter', 'keep', 'drunk', 'traffic'], ['safety', 'lock', 'must', 'ensure', 'intoxicated', 'user', 'leaf', 'scooter', 'behind'], ['used', 'drunken', 'young', 'people', 'criminal', 'therefore', 'dangerous', 'security', 'lock', 'ending', 'scooter', 'pilot', 'better', 'especially', 'option'], ['used', 'travel', 'train', 'pleasure', 'fairly', 'reliable', 'nowadays', 'absolutely', 'idea', 'whether', 'even', 'arrive', 'destination', 'whether', 'get', 'home', 'would', 'car', 'something', 'cant', 'buy', 'car', 'either', 'expensive'], ['want', 'curious', 'first', 'ride', 'car', 'drive', 'handy', 'affordable', 'wonderfully', 'sustainable', 'also', 'want', 'make', 'impact', 'together', 'book', 'first', 'ride', 'receive', 'discount'], ['recognize', 'drama', 'east', 'country', 'even', 'worse', 'run', 'default', 'exceptional', 'bizarre', 'nowadays', 'travel', 'little', 'possible', 'train', 'necessary', 'taxi', 'consider', 'car', 'share'], ['help', 'x', 'posse', 'complete', 'survey', 'share', 'call', 'people', 'context', 'thesis', 'geography', 'research', 'gender', 'gap', 'use', 'bike', 'electric', 'bike', 'scooter', 'region', 'help', 'enormously', 'survey', 'need', 'experience', 'mobility', 'yet', 'link'], ['never', 'completely', 'disappear', 'city', 'many', 'easily', 'car', 'already', 'many', 'take', 'shape'], ['lot', 'new', 'information', 'come', 'user', 'research', 'actually', 'data', 'interesting', 'conduct', 'type', 'research', 'read', 'research'], ['councilor', 'used', 'smart', 'tire', 'pump', 'band', 'took', 'car', 'tire', 'pump', 'average', 'use', 'pump', 'per', 'week', 'pump', 'free', 'found', 'ah'], ['everyone', 'drive', 'electric', 'need', 'car', 'already', 'electric'], ['goodness', 'get', 'beautiful', 'minute', 'would', 'fly', 'credit', 'score', 'high', 'enough', 'ride', 'bike'], ['nice', 'rescue', 'car', 'good', 'trip'], ['next', 'year', 'longer', 'leave', 'bicycle', 'scooter', 'anywhere'], ['electric', 'little', 'creativity', 'instead', 'eternal', 'struggle', 'money', 'mean', 'money', 'minimum', 'income', 'inventive'], ['next', 'year', 'longer', 'leave', 'bicycle', 'scooter', 'everywhere'], ['next', 'year', 'longer', 'leave', 'bicycle', 'scooter', 'everywhere'], ['go', 'straight', 'catch', 'flight', 'train', 'doesnt', 'work', 'car', 'taken', 'running', 'airport', 'take', 'suitcase', 'u', 'made', 'flight', 'cry', 'eldest', 'daughter'], ['morning', 'traveled', 'unknown', 'territory', 'way', 'back', 'turned', 'taken', 'h ...

# %%
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer

def analyze_topics(texts):
    concatenated_texts = [' '.join(tweet_list) for tweet_list in texts]

    ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)

    model = BERTopic(verbose=True, embedding_model='paraphrase-MiniLM-L3-v2', min_topic_size=6, ctfidf_model=ctfidf_model, n_gram_range=(1, 2))

    topics, _ = model.fit_transform(concatenated_texts)
    
    freq = model.get_topic_info()

    
    print("Number of topics: {}".format(len(freq)))
    display(freq.head(50))

    freq = model.get_topic_info()
    freq.to_csv('output5.csv', index=False)

    return model, topics

model, topics = analyze_topics(processed_texts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 28
#      24     freq.to_csv('output5.csv', index=False)
#      26     return model, topics
# ---> 28 model, topics = analyze_topics(processed_texts)
#
# Cell In[27], line 11, in analyze_topics(texts)
#       8 ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)
#      10 # Create BERTopic model
# ---> 11 model = BERTopic(verbose=True, embedding_model='paraphrase-MiniLM-L3-v2', min_topic_size=6, ctfidf_model=ctfidf_model, nr_keywords=nr_keywords)
#      13 # Fit and transform the model on the concatenated texts
#      14 topics, _ = model.fit_transform(concatenated_texts)
#
# NameError: name 'nr_keywords' is not defined

# %%
topics_df = pd.read_csv('output5.csv', sep=',')

display(topics_df)
# Out:
#     Topic  Count                                               Name  \
# 0      -1    259                      -1_also_private_electric_take
# 1       0     93      0_scooter_bicycle scooter_bicycle_scooter car
# 2       1     83                        1_car car_like_rid car_dont
# 3       2     78         2_transport_public_public transport_future
# 4       3     52        3_bicycle_public transport_public_transport
# 5       4     45       4_hub_neighborhood_neighborhood hub_district
# 6       5     34      5_electric car_electric_pump_already electric
# 7       6     30         6_public transport_public_transport_travel
# 8       7     29  7_electric_premium_electric electric_electric ...
# 9       8     28         8_bicycle_bike_person injured_fall bicycle
# 10      9     26      9_parking_permit_parking space_parking permit
# 11     10     25             10_ownership_rental_rent_car ownership
# 12     11     21              11_mobility_mobility hub_hub_transfer
# 13     12     21            12_year_evident_year found_year evident
# 14     13     19             13_completely_never_many_nothing happy
# 15     14     17                   14_expensive_every day_use_every
# 16     15     16  15_walking distance_within walking_distance_wi...
# 17     16     15  16_battery_possible work_battery one_one electric
# 18     17     13               17_endura_initiative_project_meeting
# 19     18     13               18_great_via_hey available_via great
# 20     19     13   19_mobility_car mobility_sustainable_people need
# 21     20     11                  20_solar_drive solar_drive_energy
# 22     21     11  21_charging_municipality charging_charging ele...
# 23     22     11          22_fleet_flemish_already electric_already
# 24     23     10  23_parking city_transport success_center make_...
# 25     24     10  24_electricity_first supply_world first_supply...
# 26     25     10                   25_car none_none_never_car never
# 27     26      9   26_parking pressure_pressure_quite hassle_combat
# 28     27      8              27_research_user research_user_report
# 29     28      8                       28_first ride_ride_book_trip
# 30     29      8                    29_front_door_stolen car_stolen
# 31     30      7    30_private_private car_private ownership_honest
# 32     31      7                31_fire_water_bicycle fire_fire bus
#
#                                        Representation  \
# 0   ['also', 'private', 'electric', 'take', 'time'...
# 1   ['scooter', 'bicycle scooter', 'bicycle', 'sco...
# 2   ['car car', 'like', 'rid car', 'dont', 'still'...
# 3   ['transport', 'public', 'public transport', 'f...
# 4   ['bicycle', 'public transport', 'public', 'tra...
# 5   ['hub', 'neighborhood', 'neighborhood hub', 'd...
# 6   ['electric car', 'electric', 'pump', 'already ...
# 7   ['public transport', 'public', 'transport', 't...
# 8   ['electric', 'premium', 'electric electric', '...
# 9   ['bicycle', 'bike', 'person injured', 'fall bi...
# 10  ['parking', 'permit', 'parking space', 'parkin...
# 11  ['ownership', 'rental', 'rent', 'car ownership...
# 12  ['mobility', 'mobility hub', 'hub', 'transfer'...
# 13  ['year', 'evident', 'year found', 'year eviden...
# 14  ['completely', 'never', 'many', 'nothing happy...
# 15  ['expensive', 'every day', 'use', 'every', 'da...
# 16  ['walking distance', 'within walking', 'distan...
# 17  ['battery', 'possible work', 'battery one', 'o...
# 18  ['endura', 'initiative', 'project', 'meeting',...
# 19  ['great', 'via', 'hey available', 'via great',...
# 20  ['mobility', 'car mobility', 'sustainable', 'p...
# 21  ['solar', 'drive solar', 'drive', 'energy', 'c...
# 22  ['charging', 'municipality charging', 'chargin...
# 23  ['fleet', 'flemish', 'already electric', 'alre...
# 24  ['parking city', 'transport success', 'center ...
# 25  ['electricity', 'first supply', 'world first',...
# 26  ['car none', 'none', 'never', 'car never', 'no...
# 27  ['parking pressure', 'pressure', 'quite hassle...
# 28  ['research', 'user research', 'user', 'report'...
# 29  ['first ride', 'ride', 'book', 'trip', 'first'...
# 30  ['front', 'door', 'stolen car', 'stolen', 'car...
# 31  ['private', 'private car', 'private ownership'...
# 32  ['fire', 'water', 'bicycle fire', 'fire bus', ...
#
#                                   Representative_Docs Keep?  Combine?  \
# 0   ['mobility known time building city accessibil...     -       NaN
# 1   ['bicycle scooter car think let u know via sho...     -       NaN
# 2   ['hi ask pick billy yet received response whet...     -       NaN
# 3   ['affordable reliable public transport electri...     -       NaN
# 4   ['plenty available within walking distance alt...     +       NaN
# 5   ['consultation supervision enforcement another...     -       NaN
# 6   ['trying electric car easy get family petrol c...     -       NaN
# 7   ['never happen car always full often need loca...     -       NaN
# 8   ['already possible rent electric may also poss...     -       NaN
# 9   ['person injured fall bicycle', 'person injure...     -       NaN
# 10  ['also difficult find parking space neighborho...     +       NaN
# 11  ['car principle work well speaking experience ...     +       NaN
# 12  ['state mobility collaboration program respons...     -       NaN
# 13  ['another month flown lot new spread throughou...     -       NaN
# 14  ['absolutely chance unfortunately little madne...     -       NaN
# 15  ['dont people share caravan example use much l...     +       NaN
# 16  ['top looking number per share car within walk...     -       NaN
# 17  ['battery one electric car supply power possib...     -       NaN
# 18  ['share car together neighborhood endura proje...     -       NaN
# 19  ['great strange', 'municipality indirectly sub...     -       NaN
# 20  ['correct understandable also sustainable situ...     +       NaN
# 21  ['drive solar collaborate', 'drive solar charg...     +       NaN
# 22  ['buy electronic install charging guarantee en...     -       NaN
# 23  ['entire fleet already electric considerably h...     -       NaN
# 24  ['parking city center make transport success',...     -       NaN
# 25  ['world first supply electricity', 'world firs...     -       NaN
# 26  ['leave nothing happy car maybe car unaffordab...     +       NaN
# 27  ['well combat parking pressure sometimes quite...     -       NaN
# 28  ['curious user research important found knowin...     -       NaN
# 29  ['want curious first ride car drive handy affo...     -       NaN
# 30  ['car exactly way want front near door car hom...     -       NaN
# 31  ['part discouragement strategy want ban privat...     +       NaN
# 32  ['found abandoned bicycle side water emergency...     -       NaN
#
#                                           Description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Expressing their please for shared mobility be...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Expressing their frustration finding parking s...
# 11  The positive and negative sides of driving/own...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                        Cars being expensive to own
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                      car ownership
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                       car ownership, unaffordable?
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                              crime
# 31  Subsidise private car ownership to nudge towar...
# 32                                                NaN

# %%
topics_df = topics_df[['Count', 'Name', 'Representation', 'Representative_Docs']]
display(topics_df)
# Out:
#     Count                                               Name  \
# 0     259                      -1_also_private_electric_take
# 1      93      0_scooter_bicycle scooter_bicycle_scooter car
# 2      83                        1_car car_like_rid car_dont
# 3      78         2_transport_public_public transport_future
# 4      52        3_bicycle_public transport_public_transport
# 5      45       4_hub_neighborhood_neighborhood hub_district
# 6      34      5_electric car_electric_pump_already electric
# 7      30         6_public transport_public_transport_travel
# 8      29  7_electric_premium_electric electric_electric ...
# 9      28         8_bicycle_bike_person injured_fall bicycle
# 10     26      9_parking_permit_parking space_parking permit
# 11     25             10_ownership_rental_rent_car ownership
# 12     21              11_mobility_mobility hub_hub_transfer
# 13     21            12_year_evident_year found_year evident
# 14     19             13_completely_never_many_nothing happy
# 15     17                   14_expensive_every day_use_every
# 16     16  15_walking distance_within walking_distance_wi...
# 17     15  16_battery_possible work_battery one_one electric
# 18     13               17_endura_initiative_project_meeting
# 19     13               18_great_via_hey available_via great
# 20     13   19_mobility_car mobility_sustainable_people need
# 21     11                  20_solar_drive solar_drive_energy
# 22     11  21_charging_municipality charging_charging ele...
# 23     11          22_fleet_flemish_already electric_already
# 24     10  23_parking city_transport success_center make_...
# 25     10  24_electricity_first supply_world first_supply...
# 26     10                   25_car none_none_never_car never
# 27      9   26_parking pressure_pressure_quite hassle_combat
# 28      8              27_research_user research_user_report
# 29      8                       28_first ride_ride_book_trip
# 30      8                    29_front_door_stolen car_stolen
# 31      7    30_private_private car_private ownership_honest
# 32      7                31_fire_water_bicycle fire_fire bus
#
#                                        Representation  \
# 0   ['also', 'private', 'electric', 'take', 'time'...
# 1   ['scooter', 'bicycle scooter', 'bicycle', 'sco...
# 2   ['car car', 'like', 'rid car', 'dont', 'still'...
# 3   ['transport', 'public', 'public transport', 'f...
# 4   ['bicycle', 'public transport', 'public', 'tra...
# 5   ['hub', 'neighborhood', 'neighborhood hub', 'd...
# 6   ['electric car', 'electric', 'pump', 'already ...
# 7   ['public transport', 'public', 'transport', 't...
# 8   ['electric', 'premium', 'electric electric', '...
# 9   ['bicycle', 'bike', 'person injured', 'fall bi...
# 10  ['parking', 'permit', 'parking space', 'parkin...
# 11  ['ownership', 'rental', 'rent', 'car ownership...
# 12  ['mobility', 'mobility hub', 'hub', 'transfer'...
# 13  ['year', 'evident', 'year found', 'year eviden...
# 14  ['completely', 'never', 'many', 'nothing happy...
# 15  ['expensive', 'every day', 'use', 'every', 'da...
# 16  ['walking distance', 'within walking', 'distan...
# 17  ['battery', 'possible work', 'battery one', 'o...
# 18  ['endura', 'initiative', 'project', 'meeting',...
# 19  ['great', 'via', 'hey available', 'via great',...
# 20  ['mobility', 'car mobility', 'sustainable', 'p...
# 21  ['solar', 'drive solar', 'drive', 'energy', 'c...
# 22  ['charging', 'municipality charging', 'chargin...
# 23  ['fleet', 'flemish', 'already electric', 'alre...
# 24  ['parking city', 'transport success', 'center ...
# 25  ['electricity', 'first supply', 'world first',...
# 26  ['car none', 'none', 'never', 'car never', 'no...
# 27  ['parking pressure', 'pressure', 'quite hassle...
# 28  ['research', 'user research', 'user', 'report'...
# 29  ['first ride', 'ride', 'book', 'trip', 'first'...
# 30  ['front', 'door', 'stolen car', 'stolen', 'car...
# 31  ['private', 'private car', 'private ownership'...
# 32  ['fire', 'water', 'bicycle fire', 'fire bus', ...
#
#                                   Representative_Docs
# 0   ['mobility known time building city accessibil...
# 1   ['bicycle scooter car think let u know via sho...
# 2   ['hi ask pick billy yet received response whet...
# 3   ['affordable reliable public transport electri...
# 4   ['plenty available within walking distance alt...
# 5   ['consultation supervision enforcement another...
# 6   ['trying electric car easy get family petrol c...
# 7   ['never happen car always full often need loca...
# 8   ['already possible rent electric may also poss...
# 9   ['person injured fall bicycle', 'person injure...
# 10  ['also difficult find parking space neighborho...
# 11  ['car principle work well speaking experience ...
# 12  ['state mobility collaboration program respons...
# 13  ['another month flown lot new spread throughou...
# 14  ['absolutely chance unfortunately little madne...
# 15  ['dont people share caravan example use much l...
# 16  ['top looking number per share car within walk...
# 17  ['battery one electric car supply power possib...
# 18  ['share car together neighborhood endura proje...
# 19  ['great strange', 'municipality indirectly sub...
# 20  ['correct understandable also sustainable situ...
# 21  ['drive solar collaborate', 'drive solar charg...
# 22  ['buy electronic install charging guarantee en...
# 23  ['entire fleet already electric considerably h...
# 24  ['parking city center make transport success',...
# 25  ['world first supply electricity', 'world firs...
# 26  ['leave nothing happy car maybe car unaffordab...
# 27  ['well combat parking pressure sometimes quite...
# 28  ['curious user research important found knowin...
# 29  ['want curious first ride car drive handy affo...
# 30  ['car exactly way want front near door car hom...
# 31  ['part discouragement strategy want ban privat...
# 32  ['found abandoned bicycle side water emergency...

# %%
topics_df = topics_df.drop([0, 1, 2 , 3, 5, 6, 7, 8, 9, 12, 13, 14, 16, 17, 18, 19, 22, 23, 24, 25, 27, 28, 29, 30, 32])

# %%
display(topics_df)
# Out:
#     Count                                              Name  \
# 4      52       3_bicycle_public transport_public_transport
# 10     26     9_parking_permit_parking space_parking permit
# 11     25            10_ownership_rental_rent_car ownership
# 15     17                  14_expensive_every day_use_every
# 20     13  19_mobility_car mobility_sustainable_people need
# 21     11                 20_solar_drive solar_drive_energy
# 26     10                  25_car none_none_never_car never
# 31      7   30_private_private car_private ownership_honest
#
#                                        Representation  \
# 4   ['bicycle', 'public transport', 'public', 'tra...
# 10  ['parking', 'permit', 'parking space', 'parkin...
# 11  ['ownership', 'rental', 'rent', 'car ownership...
# 15  ['expensive', 'every day', 'use', 'every', 'da...
# 20  ['mobility', 'car mobility', 'sustainable', 'p...
# 21  ['solar', 'drive solar', 'drive', 'energy', 'c...
# 26  ['car none', 'none', 'never', 'car never', 'no...
# 31  ['private', 'private car', 'private ownership'...
#
#                                   Representative_Docs
# 4   ['plenty available within walking distance alt...
# 10  ['also difficult find parking space neighborho...
# 11  ['car principle work well speaking experience ...
# 15  ['dont people share caravan example use much l...
# 20  ['correct understandable also sustainable situ...
# 21  ['drive solar collaborate', 'drive solar charg...
# 26  ['leave nothing happy car maybe car unaffordab...
# 31  ['part discouragement strategy want ban privat...

# %%
import requests

def analyze_sentiment(text):
    url = "http://text-processing.com/api/sentiment/"
    data = {'text': text, 'language': 'dutch'}

    response = requests.post(url, data=data)
    result = response.json()

    sentiment = result['label']
    confidence = result['probability'][sentiment]

    return sentiment, confidence


topics_df['sentiment'], topics_df['confidence'] = zip(*topics_df['Representative_Docs'].apply(analyze_sentiment))

display(topics_df)
# Out:
#     Count                                              Name  \
# 4      52       3_bicycle_public transport_public_transport
# 10     26     9_parking_permit_parking space_parking permit
# 11     25            10_ownership_rental_rent_car ownership
# 15     17                  14_expensive_every day_use_every
# 20     13  19_mobility_car mobility_sustainable_people need
# 21     11                 20_solar_drive solar_drive_energy
# 26     10                  25_car none_none_never_car never
# 31      7   30_private_private car_private ownership_honest
#
#                                        Representation  \
# 4   ['bicycle', 'public transport', 'public', 'tra...
# 10  ['parking', 'permit', 'parking space', 'parkin...
# 11  ['ownership', 'rental', 'rent', 'car ownership...
# 15  ['expensive', 'every day', 'use', 'every', 'da...
# 20  ['mobility', 'car mobility', 'sustainable', 'p...
# 21  ['solar', 'drive solar', 'drive', 'energy', 'c...
# 26  ['car none', 'none', 'never', 'car never', 'no...
# 31  ['private', 'private car', 'private ownership'...
#
#                                   Representative_Docs sentiment  confidence
# 4   ['plenty available within walking distance alt...   neutral         1.0
# 10  ['also difficult find parking space neighborho...   neutral         1.0
# 11  ['car principle work well speaking experience ...       neg         0.6
# 15  ['dont people share caravan example use much l...   neutral         1.0
# 20  ['correct understandable also sustainable situ...       neg         0.6
# 21  ['drive solar collaborate', 'drive solar charg...   neutral         1.0
# 26  ['leave nothing happy car maybe car unaffordab...   neutral         1.0
# 31  ['part discouragement strategy want ban privat...       neg         0.6

# %%
topics_df['Description'] = ['Expressing appreciation for the accessibility of shared mobility solutions, conveniently located within a short walking distance.', 'Expressing dissatisfaction with the challenge of finding parking spaces in the neighborhood, contemplating the decision not to renew their parking permit.', 'Advocacy for convenient shared mobility to reduce reliance on traditional car ownership models, making urban living more sustainable and affordable.', 'Promoting the idea of using shared cars for everyday needs to minimise expenses', 'Advocating for governments to play a crucial role by implementing policies to reduce the number of cars and encourage alternative modes of transportation', 'Embracing solar-powered driving', 'Reflecting on the challenges of car ownership, contemplating alternatives due to rising fuel prices, and considering family safety in the decision-making process.', 'Advocating for a discouragement strategy to ban private car ownership in favor of public transportation, bicycles, and walking within accessible distances.']

# %%
display(topics_df)
# Out:
#     Count                                              Name  \
# 4      52       3_bicycle_public transport_public_transport
# 10     26     9_parking_permit_parking space_parking permit
# 11     25            10_ownership_rental_rent_car ownership
# 15     17                  14_expensive_every day_use_every
# 20     13  19_mobility_car mobility_sustainable_people need
# 21     11                 20_solar_drive solar_drive_energy
# 26     10                  25_car none_none_never_car never
# 31      7   30_private_private car_private ownership_honest
#
#                                        Representation  \
# 4   ['bicycle', 'public transport', 'public', 'tra...
# 10  ['parking', 'permit', 'parking space', 'parkin...
# 11  ['ownership', 'rental', 'rent', 'car ownership...
# 15  ['expensive', 'every day', 'use', 'every', 'da...
# 20  ['mobility', 'car mobility', 'sustainable', 'p...
# 21  ['solar', 'drive solar', 'drive', 'energy', 'c...
# 26  ['car none', 'none', 'never', 'car never', 'no...
# 31  ['private', 'private car', 'private ownership'...
#
#                                   Representative_Docs sentiment  confidence  \
# 4   ['plenty available within walking distance alt...   neutral         1.0
# 10  ['also difficult find parking space neighborho...   neutral         1.0
# 11  ['car principle work well speaking experience ...       neg         0.6
# 15  ['dont people share caravan example use much l...   neutral         1.0
# 20  ['correct understandable also sustainable situ...       neg         0.6
# 21  ['drive solar collaborate', 'drive solar charg...   neutral         1.0
# 26  ['leave nothing happy car maybe car unaffordab...   neutral         1.0
# 31  ['part discouragement strategy want ban privat...       neg         0.6
#
#                                           Description
# 4   Expressing appreciation for the accessibility ...
# 10  Expressing dissatisfaction with the challenge ...
# 11  Advocacy for convenient shared mobility to red...
# 15  Promoting the idea of using shared cars for ev...
# 20  Advocating for governments to play a crucial r...
# 21                    Embracing solar-powered driving
# 26  Reflecting on the challenges of car ownership,...
# 31  Advocating for a discouragement strategy to ba...

# %%
topics_df.to_csv('final_analysed_topics.csv', index=False)
